# %% [markdown]
# ## DrugCell Code in the Notebook

# %%
import sys
import os
import numpy as np
import pandas as pd
import torch
import torch.utils.data as du
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import argparse
from torch import optim
import numpy as np
import time
import sklearn
import networkx as nx
import networkx.algorithms.components.connected as nxacc
import networkx.algorithms.dag as nxadag
import torch.utils.data as du
from torch.autograd import Variable
from time import time
import candle
import logging
from torchmetrics.functional import mean_absolute_error
from scipy.stats import spearmanr
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import gc
torch.cuda.empty_cache()
#del variables
gc.collect()
#print("hello")
import improve_utils 
from pathlib import Path
from math import sqrt
from scipy import stats
from typing import List, Union, Optional
from improve_utils import load_cell_mutation_data
# %matplotlib inline
# Out:
# Importing candle utils for pytorch

# %%
#fdir = Path('__file__').resolve().parent
#source = "csa_data/raw_data/splits/"
#rs = improve_utils.load_single_drug_response_data(source="CCLE", split=0, split_type=["train", "val"])
#rs_all = improve_utils.load_single_drug_response_data(source="CCLE", split=0, split_type=["train", "test", 'val'], y_col_name="auc")
#rs_train = improve_utils.load_single_drug_response_data(source="CCLE", split=0, split_type=["train"], y_col_name="auc1")
#rs_test = improve_utils.load_single_drug_response_data(source="CCLE", split=0, split_type=["test"], y_col_name="auc1")
#rs_val = improve_utils.load_single_drug_response_data(source="CCLE", split=0, split_type=["val"], y_col_name="auc1")


#data_df = rs_all
model_name='DrugCell'
CUDA_ID = 0
data_url="http://drugcell.ucsd.edu/downloads/data.tgz"
original_data="data.tgz"
data_model='drugcell_v1.pt'
predict_url = 'http://drugcell.ucsd.edu/downloads/drugcell_all.txt'
model_url = 'http://drugcell.ucsd.edu/downloads/drugcell_v1.pt'
onto = "../NOTEBOOK/drugcell_ont.txt"
hidden='OUTPUT/MODEL/Hidden/'
result='OUTPUT/MODEL/Result/'
learning_rate = 0.0001
batch_size = 256
eps=0.00001
genotype_hiddens = 6
drug_hiddens='100,50,6'
final_hiddens=6
output_dir = "."
epochs=3
#weight_decay=1e-3
iteration="ANL"
decay_rate = learning_rate / epochs
optimizer = "adam"
loss = "mse"

# %% [markdown]
# ## ANL INPUTS

# %%
# CTRPv2


#data_predict='../CTRPv2/drugcell_test.txt'
#data_dir = "../CTRPv2/"
#train_data_file = "../CTRPv2/drugcell_train.txt"
#test_data_file = "../CTRPv2/drugcell_test.txt"
#val_data_file = "../CTRPv2/drugcell_val.txt"
#genotype="../CTRPv2/cell2mutation.txt"
#fingerprint='../CTRPv2/drug2fingerprint.txt'
#cell2id='../CTRPv2/cell2ind.txt'
#drug2id='../CTRPv2/drug2ind.txt'
#gene2id='../CTRPv2/gene2ind.txt'

# %%
#CCLE
data_predict='../CCLE/drugcell_test.txt'
data_dir = "../CCLE/"
train_data_file = "../CCLE/drugcell_train.txt"
test_data_file = "../CCLE/drugcell_test.txt"
val_data_file = "../CCLE/drugcell_val.txt"
genotype="../CCLE/cell2mutation.txt"
fingerprint='../CCLE/drug2fingerprint.txt'
cell2id='../CCLE/cell2ind.txt'
drug2id='../CCLE/drug2ind.txt'
gene2id='../CCLE/gene2ind.txt'

# %% [markdown]
# ## INPUTS

# %%
#AUTHOR
#data_dir = "data/"
#train_data_file = "../data/drugcell_train.txt"
#test_data_file = "../data/drugcell_test.txt"
#val_data_file = "../data/drugcell_val.txt"
#onto = "../data/drugcell_ont.txt"
#genotype="../data/cell2mutation.txt"
#fingerprint='../data/drug2fingerprint.txt'
#cell2id='../data//cell2ind.txt'
#drug2id='../data/drug2ind.txt'
#gene2id='../data/gene2ind.txt'

# %% [markdown]
# ## UTILS CODE

# %%
def pearson_corr(x, y):
    xx = x - torch.mean(x)
    yy = y - torch.mean(y)
    return torch.sum(xx*yy) / (torch.norm(xx, 2)*torch.norm(yy,2))


def spearman_corr(x, y):
    # Convert to ranks
    x_rank = torch.argsort(torch.argsort(x))
    y_rank = torch.argsort(torch.argsort(y))
    
    # Calculate the difference between ranks
    rank_diff = x_rank - y_rank
    
    # Calculate the Spearman correlation coefficient
    n = len(x)
    numerator = 6 * torch.sum(rank_diff**2)
    denominator = n * (n**2 - 1)
    correlation = 1 - numerator / denominator
    
    return correlation


def r2_score(y_true, y_pred):
    y_mean = torch.mean(y_true)
    ss_tot = torch.sum((y_true - y_mean)**2)
    ss_res = torch.sum((y_true - y_pred)**2)
    r2 = 1 - ss_res / ss_tot
    return r2

def calc_pcc(x, y):
    xx = x - torch.mean(x)
    yy = y - torch.mean(y)
    return torch.sum(xx*yy) / (torch.norm(xx, 2)*torch.norm(yy,2))


def mean_absolute_error(y_true, y_pred):
    absolute_errors = torch.abs(y_true - y_pred)
    mae = torch.mean(absolute_errors)
    return mae

def calc_mae(y_true, y_pred):
    return sklearn.metrics.mean_absolute_error(y_true=y_true, y_pred=y_pred)

def calc_r2(y_true, y_pred):
    target_mean = torch.mean(y_pred)
    ss_tot = torch.sum((y_pred - target_mean) ** 2)
    ss_res = torch.sum((y_pred - y_true) ** 2)
    r2 = 1 - ss_res / ss_tot
    return r2

def load_ontology(file_name, gene2id_mapping):
    dG = nx.DiGraph()
    term_direct_gene_map = {}
    term_size_map = {}
    file_handle = open(file_name)
    gene_set = set()

    for line in file_handle:
        line = line.rstrip().split()
        if line[2] == 'default':
            dG.add_edge(line[0], line[1])
        else:
            if line[1] not in gene2id_mapping:
                continue

            if line[0] not in term_direct_gene_map:
                term_direct_gene_map[ line[0] ] = set()

            term_direct_gene_map[line[0]].add(gene2id_mapping[line[1]])
            gene_set.add(line[1])

    file_handle.close()
    
    print('There are', len(gene_set), 'genes')
    for term in dG.nodes():
        term_gene_set = set()
        if term in term_direct_gene_map:
            term_gene_set = term_direct_gene_map[term]

        deslist = nxadag.descendants(dG, term)

        for child in deslist:
            if child in term_direct_gene_map:
                term_gene_set = term_gene_set | term_direct_gene_map[child]

        # jisoo
        if len(term_gene_set) == 0:
            print('There is empty terms, please delete term:', term)
            sys.exit(1)
        else:
            term_size_map[term] = len(term_gene_set)

    leaves = [n for n in dG.nodes if dG.in_degree(n) == 0]
    #leaves = [n for n,d in dG.in_degree() if d==0]

    uG = dG.to_undirected()
    connected_subG_list = list(nxacc.connected_components(uG))

    print('There are', len(leaves), 'roots:', leaves[0])
    print('There are', len(dG.nodes()), 'terms')
    print('There are', len(connected_subG_list), 'connected componenets')

    if len(leaves) > 1:
        print('There are more than 1 root of ontology. Please use only one root.')
        sys.exit(1)
    if len(connected_subG_list) > 1:
        print( 'There are more than connected components. Please connect them.')
        sys.exit(1)

    return dG, leaves[0], term_size_map, term_direct_gene_map


def load_train_data(file_name, cell2id, drug2id):
    feature = []
    label = []
    feature_dict = {}
    with open(file_name, 'r') as fi:
        for line in fi:
            tokens = line.strip().split('\t')
            keys = list(cell2id.keys())[list(cell2id.values()).index(cell2id[tokens[0]])] + ";" + list(drug2id.keys())[list(drug2id.values()).index(drug2id[tokens[1]])]
            feature.append([cell2id[tokens[0]], drug2id[tokens[1]]])
            feature_dict[keys] = [cell2id[tokens[0]], drug2id[tokens[1]]]
            label.append([float(tokens[2])])
    return feature, label, feature_dict


def load_mapping(some_file):
    mapping = {}
    with  open(some_file) as fin:
        for line in fin:
            line = line.rstrip().split()
            mapping[line[1]] = int(line[0])
    return mapping

def check_file(some_file):
    if os.path.isfile(some_file):
        print(some_file)
    else:
        print('{0} file does not exist'.format(some_file))
        exit()
        
def prepare_predict_data(test_file, cell2id_mapping_file, drug2id_mapping_file):
    cell2id_mapping = load_mapping(cell2id_mapping_file)
    drug2id_mapping = load_mapping(drug2id_mapping_file)
    test_feature, test_label, feature_dict = load_train_data(test_file, cell2id_mapping, drug2id_mapping)
#    test_feature = test_feature_dict.values()
    torch_test_feature = torch.Tensor(test_feature)
    torch_test_label = torch.Tensor(test_label)
    print('Total number of cell lines = %d' % len(cell2id_mapping))
    print('Total number of drugs = %d' % len(drug2id_mapping))
    return torch_test_feature, torch_test_label, feature_dict

def prepare_train_data(train_file, test_file, cell2id_mapping_file, drug2id_mapping_file):
    print(train_file, test_file, cell2id_mapping_file, drug2id_mapping_file)
    # load mapping files
    cell2id_mapping = load_mapping(cell2id_mapping_file)
    drug2id_mapping = load_mapping(drug2id_mapping_file)
  
    train_feature, train_label, feature_dict  = load_train_data(train_file, cell2id_mapping, drug2id_mapping)
    test_feature, test_label, feature_dict  = load_train_data(test_file, cell2id_mapping, drug2id_mapping)

    print('Total number of cell lines = %d' % len(cell2id_mapping))
    print('Total number of drugs = %d' % len(drug2id_mapping))
    return (torch.Tensor(train_feature), 
            torch.FloatTensor(train_label), 
            torch.Tensor(test_feature), 
            torch.FloatTensor(test_label)), feature_dict, cell2id_mapping, drug2id_mapping

def build_input_vector(input_data, cell_features, drug_features):
    genedim = len(cell_features[0,:])
    drugdim = len(drug_features[0,:])
    feature = np.zeros((input_data.size()[0], (genedim+drugdim)))
    #print(input_data)
    #print(drug_features)

    for i in range(input_data.size()[0]):
        #print(int(input_data[i,0]))
        try:
            feature[i] = np.concatenate((cell_features[int(input_data[i,0])], 
                                         drug_features[int(input_data[i,1])]), axis=None)
        except IndexError:
            pass

    feature = torch.from_numpy(feature).float()
    return feature

def pearsonr(x, y):
    """Compute Pearson correlation.
    Args:
        x (torch.Tensor): 1D vector
        y (torch.Tensor): 1D vector of the same size as y.
    Raises:
        TypeError: not torch.Tensors.
        ValueError: not same shape or at least length 2.
    Returns:
        Pearson correlation coefficient.
    """
    if not isinstance(x, torch.Tensor) or not isinstance(y, torch.Tensor):
        raise TypeError('Function expects torch Tensors.')

    if len(x.shape) > 1 or len(y.shape) > 1:
        raise ValueError(' x and y must be 1D Tensors.')

    if len(x) != len(y):
        raise ValueError('x and y must have the same length.')

    if len(x) < 2:
        raise ValueError('x and y must have length at least 2.')

    # If an input is constant, the correlation coefficient is not defined.
    if bool((x == x[0]).all()) or bool((y == y[0]).all()):
        raise ValueError('Constant input, r is not defined.')

    mx = x - torch.mean(x)
    my = y - torch.mean(y)
    cost = (
        torch.sum(mx * my) /
        (torch.sqrt(torch.sum(mx**2)) * torch.sqrt(torch.sum(my**2)))
    )
    return torch.clamp(cost, min=-1.0, max=1.0)

def correlation_coefficient_loss(labels, predictions):
    """Compute loss based on Pearson correlation.
    Args:
        labels (torch.Tensor): reference values
        predictions (torch.Tensor): predicted values
    Returns:
        torch.Tensor: A loss that when minimized forces high squared correlation coefficient:
        \$1 - r(labels, predictions)^2\$  # noqa
    """
    return 1 - pearsonr(labels, predictions)**2


def mse_cc_loss(labels, predictions):
    """Compute loss based on MSE and Pearson correlation.
    The main assumption is that MSE lies in [0,1] range, i.e.: range is
    comparable with Pearson correlation-based loss.
    Args:
        labels (torch.Tensor): reference values
        predictions (torch.Tensor): predicted values
    Returns:
        torch.Tensor: A loss that computes the following:
        \$mse(labels, predictions) + 1 - r(labels, predictions)^2\$  # noqa
    """
    mse_loss_fn = nn.MSELoss()
    mse_loss = mse_loss_fn(predictions, labels)
    cc_loss = correlation_coefficient_loss(labels, predictions)
    return mse_loss + cc_loss

# %% [markdown]
# ## DRUGCELL MODEL

# %%
class drugcell_nn(nn.Module):

    def __init__(self, term_size_map, term_direct_gene_map, dG, ngene, ndrug, root,
                 num_hiddens_genotype, num_hiddens_drug, num_hiddens_final):

        super(drugcell_nn, self).__init__()

        self.root = root
        self.num_hiddens_genotype = num_hiddens_genotype
        self.num_hiddens_drug = num_hiddens_drug

        # dictionary from terms to genes directly annotated with the term
        self.term_direct_gene_map = term_direct_gene_map

        # calculate the number of values in a state (term): term_size_map is the number of all genes annotated with the term
        self.cal_term_dim(term_size_map)

        # ngenes, gene_dim are the number of all genes
        self.gene_dim = ngene
        self.drug_dim = ndrug

        # add modules for neural networks to process genotypes
        self.contruct_direct_gene_layer()
        self.construct_NN_graph(dG)

        # add modules for neural networks to process drugs
        self.construct_NN_drug()

        # add modules for final layer
        final_input_size = num_hiddens_genotype + num_hiddens_drug[-1]
        self.add_module('final_linear_layer', nn.Linear(final_input_size, num_hiddens_final))
        self.add_module('final_batchnorm_layer', nn.BatchNorm1d(num_hiddens_final))
        self.add_module('final_aux_linear_layer', nn.Linear(num_hiddens_final,1))
        self.add_module('final_linear_layer_output', nn.Linear(1, 1))

    # calculate the number of values in a state (term)
    def cal_term_dim(self, term_size_map):

        self.term_dim_map = {}

        for term, term_size in term_size_map.items():
            num_output = self.num_hiddens_genotype

            # log the number of hidden variables per each term
            num_output = int(num_output)
#            print("term\t%s\tterm_size\t%d\tnum_hiddens\t%d" % (term, term_size, num_output))
            self.term_dim_map[term] = num_output


    # build a layer for forwarding gene that are directly annotated with the term
    def contruct_direct_gene_layer(self):

        for term, gene_set in self.term_direct_gene_map.items():
            if len(gene_set) == 0:
                print('There are no directed asscoiated genes for', term)
                sys.exit(1)

            # if there are some genes directly annotated with the term, add a layer taking in all genes and forwarding out only those genes
            self.add_module(term+'_direct_gene_layer', nn.Linear(self.gene_dim, len(gene_set)))


    # add modules for fully connected neural networks for drug processing
    def construct_NN_drug(self):
        input_size = self.drug_dim

        for i in range(len(self.num_hiddens_drug)):
            self.add_module('drug_linear_layer_' + str(i+1), nn.Linear(input_size, self.num_hiddens_drug[i]))
            self.add_module('drug_batchnorm_layer_' + str(i+1), nn.BatchNorm1d(self.num_hiddens_drug[i]))
            self.add_module('drug_aux_linear_layer1_' + str(i+1), nn.Linear(self.num_hiddens_drug[i],1))
            self.add_module('drug_aux_linear_layer2_' + str(i+1), nn.Linear(1,1))

            input_size = self.num_hiddens_drug[i]


    # start from bottom (leaves), and start building a neural network using the given ontology
    # adding modules --- the modules are not connected yet
    def construct_NN_graph(self, dG):

        self.term_layer_list = []   # term_layer_list stores the built neural network
        self.term_neighbor_map = {}

        # term_neighbor_map records all children of each term
        for term in dG.nodes():
            self.term_neighbor_map[term] = []
            for child in dG.neighbors(term):
                self.term_neighbor_map[term].append(child)

        while True:
            leaves = [n for n in dG.nodes() if dG.out_degree(n) == 0]
            #leaves = [n for n,d in dG.out_degree().items() if d==0]
            #leaves = [n for n,d in dG.out_degree() if d==0]

            if len(leaves) == 0:
                break

            self.term_layer_list.append(leaves)

            for term in leaves:

                # input size will be #chilren + #genes directly annotated by the term
                input_size = 0

                for child in self.term_neighbor_map[term]:
                    input_size += self.term_dim_map[child]

                if term in self.term_direct_gene_map:
                    input_size += len(self.term_direct_gene_map[term])

                # term_hidden is the number of the hidden variables in each state
                term_hidden = self.term_dim_map[term]

                self.add_module(term+'_linear_layer', nn.Linear(input_size, term_hidden))
                self.add_module(term+'_batchnorm_layer', nn.BatchNorm1d(term_hidden))
                self.add_module(term+'_aux_linear_layer1', nn.Linear(term_hidden,1))
                self.add_module(term+'_aux_linear_layer2', nn.Linear(1,1))

            dG.remove_nodes_from(leaves)


    # definition of forward function
    def forward(self, x):
        gene_input = x.narrow(1, 0, self.gene_dim)
        drug_input = x.narrow(1, self.gene_dim, self.drug_dim)

        # define forward function for genotype dcell #############################################
        term_gene_out_map = {}

        for term, _ in self.term_direct_gene_map.items():
            term_gene_out_map[term] = self._modules[term + '_direct_gene_layer'](gene_input)

        term_NN_out_map = {}
        aux_out_map = {}

        for i, layer in enumerate(self.term_layer_list):

            for term in layer:

                child_input_list = []

                for child in self.term_neighbor_map[term]:
                    child_input_list.append(term_NN_out_map[child])

                if term in self.term_direct_gene_map:
                    child_input_list.append(term_gene_out_map[term])

                child_input = torch.cat(child_input_list,1)

                term_NN_out = self._modules[term+'_linear_layer'](child_input)

                Tanh_out = torch.tanh(term_NN_out)
                term_NN_out_map[term] = self._modules[term+'_batchnorm_layer'](Tanh_out)
                aux_layer1_out = torch.tanh(self._modules[term+'_aux_linear_layer1'](term_NN_out_map[term]))
                aux_out_map[term] = self._modules[term+'_aux_linear_layer2'](aux_layer1_out)

        # define forward function for drug dcell #################################################
        drug_out = drug_input

        for i in range(1, len(self.num_hiddens_drug)+1, 1):
            drug_out = self._modules['drug_batchnorm_layer_'+str(i)]( torch.tanh(self._modules['drug_linear_layer_' + str(i)](drug_out)))
            term_NN_out_map['drug_'+str(i)] = drug_out

            aux_layer1_out = torch.tanh(self._modules['drug_aux_linear_layer1_'+str(i)](drug_out))
            aux_out_map['drug_'+str(i)] = self._modules['drug_aux_linear_layer2_'+str(i)](aux_layer1_out)

        # connect two neural networks at the top #################################################
        final_input = torch.cat((term_NN_out_map[self.root], drug_out), 1)

        out = self._modules['final_batchnorm_layer'](torch.tanh(self._modules['final_linear_layer'](final_input)))
        term_NN_out_map['final'] = out

        aux_layer_out = torch.tanh(self._modules['final_aux_linear_layer'](out))
        aux_out_map['final'] = self._modules['final_linear_layer_output'](aux_layer_out)

        return aux_out_map, term_NN_out_map

# %% [markdown]
# ## TRAINING

# %%
def create_term_mask(term_direct_gene_map, gene_dim, cuda):
    term_mask_map = {}
    for term, gene_set in term_direct_gene_map.items():
        mask = torch.zeros(len(gene_set), gene_dim)
        for i, gene_id in enumerate(gene_set):
            mask[i, gene_id] = 1
            mask_gpu = torch.autograd.Variable(mask.cuda(cuda))
            term_mask_map[term] = mask_gpu
    return term_mask_map

# %%
def train_model(root, term_size_map, term_direct_gene_map, dG, train_data, 
                gene_dim, drug_dim, model_save_folder, train_epochs, batch_size, 
                learning_rate, num_hiddens_genotype, num_hiddens_drug, num_hiddens_final, 
                cell_features, drug_features):
    t = time()
    epoch_start_time = time()
    best_model = 0
    max_corr = 0
    logger = logging.getLogger(f'{model_name}')
    save_top_model = os.path.join(model_save_folder, 'results/drugcell_{}_{}.pt')
    model = drugcell_nn(term_size_map, term_direct_gene_map, dG, num_genes,
                        drug_dim, root, num_hiddens_genotype, num_hiddens_drug, num_hiddens_final)
    train_feature, train_label, test_feature, test_label = train_data

    device = torch.device("cuda")
    model.to(device)
    model.cuda(CUDA_ID)
    
    train_label_gpu = torch.autograd.Variable(train_label.cuda(CUDA_ID))
    test_label_gpu = torch.autograd.Variable(test_label.cuda(CUDA_ID))
    term_mask_map = create_term_mask(model.term_direct_gene_map, num_genes, CUDA_ID)

    # Define optimizer
    optimizer_dict = {"adam": "optim.adam"}
    #optim_value = optimizer
    optimizer = optim.Adam(model.parameters(),
                           lr=learning_rate,
                           betas=(0.9, 0.99),
                           weight_decay=1e-5,
                           eps=eps)
    optimizer.zero_grad()
    scores = {}
    epoch_list = []
    train_loss_list = []
    train_corr_list = []
    train_scc_list = []
    test_loss_list = []
    test_corr_list = []
    test_scc_list = []
    for name, param in model.named_parameters():
        term_name = name.split('_')[0]
        if '_direct_gene_layer.weight' in name:
            param.data = torch.mul(param.data, term_mask_map[term_name]) * 0.1
        else:
            param.data = param.data * 0.1

    train_loader = du.DataLoader(du.TensorDataset(train_feature,train_label),
                                 batch_size=batch_size, shuffle=False)

    test_loader = du.DataLoader(du.TensorDataset(test_feature,test_label),
                                batch_size=batch_size, shuffle=False)

    for epoch in range(epochs):
        model.train()
        epoch_list.append(epoch)
        train_predict =  torch.zeros(0,0).cuda(CUDA_ID)
        #logger.info(f"== Epoch [{epoch}/epochs}] ==")
        train_loss_mean = 0
        t = time()    
        for i, (inputdata, labels) in enumerate(train_loader):
            features = build_input_vector(inputdata, cell_features, drug_features)
            cuda_features = torch.autograd.Variable(features.cuda(CUDA_ID))
            cuda_labels = torch.autograd.Variable(labels.cuda(CUDA_ID))

            optimizer.zero_grad()
            aux_out_map, _ = model(cuda_features)

            if train_predict.size()[0] == 0:
                train_predict = aux_out_map['final'].data
            else:
                train_predict = torch.cat([train_predict, aux_out_map['final'].data], dim=0)

            train_loss = 0
            count = 0
            for name, output in aux_out_map.items():
                count +=1
                loss = nn.MSELoss()
                if name == 'final':
                    train_loss += loss(output, cuda_labels)
                else:
                    train_loss += 0.2 * loss(output, cuda_labels)
            train_loss.backward()
#            train_loss_mean = train_loss/count
            train_loss_mean = train_loss
            for name, param in model.named_parameters():
                if '_direct_gene_layer.weight' not in name:
                    continue
                term_name = name.split('_')[0]
                param.grad.data = torch.mul(param.grad.data, term_mask_map[term_name])

            optimizer.step()
        #epoch_train_test_df['train_loss'] = train_loss_mean.cpu().detach().numpy()/len(train_loader)
        train_loss_list.append(train_loss_mean.cpu().detach().numpy()/len(train_loader))
        logger.info(
            "\t **** TRAINING ****   "
            f"Epoch [{epoch + 1}/{epochs}], "
            f"loss: {train_loss_mean / len(train_loader):.5f}. "
            f"This took {time() - t:.1f} secs."
        )
        
        train_corr = pearson_corr(train_predict, train_label_gpu)
        train_corr_list.append(train_corr.cpu().detach().numpy())
        torch.save(model, model_save_folder + '/model_' + str(epoch) + '.pt')
        train_predictions = np.array([p.cpu() for preds in train_predict for p in preds],dtype = np.float)
        train_predictions = train_predictions[0:len(train_predictions)]
        train_labels = np.array([l.cpu() for label in train_label_gpu for l in label],dtype = np.float)
        train_scc = spearmanr(train_labels, train_predictions)[0]
        train_scc_list.append(train_scc)
        model.eval()

        test_predict = torch.zeros(0,0).cuda(CUDA_ID)
        loss_fn = nn.MSELoss()
        test_loss = 0.0
        num_samples = 0
        tissue = []
        drug = []
        for i, (inputdata, labels) in enumerate(test_loader):
            features = build_input_vector(inputdata, cell_features, drug_features)
            cuda_features = Variable(features.cuda(CUDA_ID))
            cuda_labels = torch.autograd.Variable(labels.cuda(CUDA_ID))
            aux_out_map, _ = model(cuda_features)
            values = inputdata.cpu().detach().numpy().tolist()
            keys = [i for i in feature_dict for x in values if feature_dict [i]== x ]
            tissue = [i.split(';')[0] for i in keys]
            drug = [i.split(';')[1] for i in keys]
            if test_predict.size()[0] == 0:
                test_predict = aux_out_map['final'].data
            else:
                test_predict = torch.cat([test_predict, aux_out_map['final'].data], dim=0)
        batch_loss = loss_fn(aux_out_map['final'], cuda_labels)
        test_loss += batch_loss.item() * len(inputdata)
        num_samples += len(inputdata)  
        logger.info(
            "\t **** TEST ****   "
            f"Epoch [{epoch + 1}/{epochs}], "
            f"loss: {test_loss / len(test_loader):.5f}. "
            f"This took {time() - t:.1f} secs."
        )
        predictions = np.array([p.cpu() for preds in test_predict for p in preds] ,dtype = np.float )
        predictions = predictions[0:len(predictions)]
        labels = np.array([l.cpu() for label in labels for l in label],dtype = np.float)
        labels = labels[0:len(labels)]
        test_pearson_a = pearson_corr(test_predict, test_label_gpu)
        test_spearman_a = spearman_corr(test_predict, test_label_gpu)
        test_mean_absolute_error = mean_absolute_error(test_label_gpu, test_predict)
        test_r2 = r2_score(test_label_gpu, test_predict)
        #test_rmse_a = np.sqrt(np.mean((predictions - labels)**2))
        test_loss_a = test_loss / len(test_loader)
        test_loss_list.append(test_loss_a)
        test_corr_list.append(test_pearson_a.cpu().detach().numpy())
        test_scc_list.append(test_spearman_a.cpu().detach().numpy())
        epoch_end_time = time()
        if epoch == 0:
            min_test_loss = test_loss_a
            scores['test_loss'] = min_test_loss
            scores['test_pcc'] = test_pearson_a.cpu().detach().numpy().tolist()
            scores['test_MSE'] = test_mean_absolute_error.cpu().detach().numpy().tolist()
            scores['test_r2'] = test_r2.cpu().detach().numpy().tolist()
            scores['test_scc'] = test_spearman_a.cpu().detach().numpy().tolist()
        if test_spearman_a < min_test_loss:
            min_test_loss = test_loss_a
            scores['test_loss'] = min_test_loss
            scores['test_pcc'] = test_pearson_a.cpu().detach().numpy().tolist()
            scores['test_MSE'] = test_mean_absolute_error.cpu().detach().numpy().tolist()
            scores['test_r2'] = test_r2.cpu().detach().numpy().tolist()
            scores['test_scc'] = test_spearman_a.cpu().detach().numpy().tolist()

        if test_spearman_a >= max_corr:
            max_corr = test_spearman_a
            best_model = epoch
            #pred = pd.DataFrame({"Tissue": tissue, "Drug": drug, "True": labels, "Pred": predictions}).reset_index()
            fname='/results/test_pred_' + iteration +".csv"
            pred_fname = str(model_save_folder+ "/" + fname)
            #pred.to_csv(pred_fname, index=False)
#        print("epoch\t%d\tcuda_id\t%d\ttrain_corr\t%.6f\tval_corr\t%.6f\ttrain_loss\t%.6f\telapsed_time\t%s" % (epoch,
#                                                                                                                CUDA_ID,
#                                                                                                                train_corr, test_corr,
#                                                                                                                train_loss, epoch_end_time-epoch_start_time))
        epoch_start_time = epoch_end_time
        #ckpt.ckpt_epoch(epoch, test_loss_a)
    torch.save(model, model_save_folder + '/model_final.pt') 
    gc.collect()
    torch.cuda.empty_cache()
    print("Best performed model (epoch)\t%d" % best_model)
#    torch.save(save_top_model.format('epoch', '0', best_model))
    cols = ['epoch',  'train_corr', 'train_scc',  'test_corr', 'test_scc']
    epoch_train_test_df = pd.DataFrame(columns=cols, index=range(epochs))
    epoch_train_test_df['epoch'] = epoch_list
    #epoch_train_test_df['train_loss'] = train_loss_list
    epoch_train_test_df['train_corr'] = train_corr_list
    epoch_train_test_df['train_scc'] = train_scc_list    
    #epoch_train_test_df['test_loss'] = test_loss_list
    epoch_train_test_df['test_corr'] = test_corr_list
    epoch_train_test_df['test_scc'] = test_scc_list
    l_fname = 'train_val_loss_results' + iteration +".csv"
    loss_results_name = str(model_save_folder+'/' + l_fname)
    epoch_train_test_df.to_csv(loss_results_name, index=False)
    print(scores)
    return scores

# %% [markdown]
# ## INFERENCE

# %%
def predict_dcell(predict_data, gene_dim, drug_dim, model_file, hidden_folder,
                  batch_size, result_file, cell_features, drug_features, CUDA_ID,output_dir):
    feature_dim = gene_dim + drug_dim
    device = torch.device("cuda")
    model = torch.load(model_file, map_location='cuda:%d' % CUDA_ID)
    #checkpoint = torch.load(trained_model, map_location='cuda:%d' % CUDA_ID)
    model.to(device)
    predict_feature, predict_label, feature_dict = predict_data

    predict_label_gpu = predict_label.cuda(CUDA_ID)
    model.cuda(CUDA_ID)
    model.eval()

    test_loader = du.DataLoader(du.TensorDataset(predict_feature,predict_label), 
                                batch_size=batch_size, shuffle=False)
    model_dir = output_dir

    #Test
    test_predict = torch.zeros(0,0).cuda(CUDA_ID)
    term_hidden_map = {}
    test_loss = 0
    batch_num = 0
    test_loss_list = []
    test_corr_list = []
    drug_list = []
    tissue_list = []
    print("Begin test evaluation")
    for i, (inputdata, labels) in enumerate(test_loader):
        # Convert torch tensor to Variable
        cuda_labels = torch.autograd.Variable(labels.cuda(CUDA_ID))
        features = build_input_vector(inputdata, cell_features, drug_features)
        cuda_features = Variable(features.cuda(CUDA_ID), requires_grad=False)
        loss = nn.MSELoss()
        values = inputdata.cpu().detach().numpy().tolist()
        keys = [i for i in feature_dict for x in values if feature_dict [i]== x ]
        tissue = [i.split(';')[0] for i in keys]
        tissue_list.append(tissue)
        drug = [i.split(';')[1] for i in keys]
        drug_list.append(drug)
        # make prediction for test data
        aux_out_map, term_hidden_map = model(cuda_features)
        if test_predict.size()[0] == 0:
            test_predict = aux_out_map['final'].data
        else:
            test_predict = torch.cat([test_predict, aux_out_map['final'].data], dim=0)

        batch_num += 1
    predictions = np.array([p.cpu() for preds in test_predict for p in preds] ,dtype = np.float )
    predictions = predictions[0:len(predictions)]
    labels = np.array([l.cpu() for label in labels for l in label],dtype = np.float)
    labels = labels[0:len(labels)]
    test_pearson_a = pearson_corr(torch.Tensor(predictions), torch.Tensor(labels))
    test_spearman_a = spearman_corr(torch.Tensor(predictions), torch.Tensor(labels))
    test_mean_absolute_error = mean_absolute_error(test_label_gpu, test_predict)
    test_r2 = r2_score(test_label_gpu,test_predict)
    test_loss_a = test_loss / len(test_loader)
    test_loss_list.append(test_loss_a)
    test_corr_list.append(test_pearson_a.cpu().detach().numpy())
    test_scc_list.append(test_spearman_a.cpu().detach().numpy())
    min_test_loss = test_loss_a
    scores = {}
    scores['test_loss'] = min_test_loss
    scores['test_pcc'] = test_pearson_a.cpu().detach().numpy().tolist()
    scores['test_MSE'] = test_mean_absolute_error
    scores['test_r2'] = test_r2
    scores['test_scc'] = test_spearman_a
    print("Test pearson corr\t%s\t%.6f" % (model.root, test_pearson_a))
    print("Test spearman corr\t%s\t%.6f" % (model.root, test_spearman_a))
    print(scores)
    cols = ['drug', 'tissue', 'test_loss', 'test_corr', 'test_scc']
    metrics_test_df = pd.DataFrame(columns=cols, index=range(len(test_loader)))
    metrics_test_df['test_loss'] = test_loss_list
    metrics_test_df['test_corr'] = test_corr_list
    
    lr_name = 'test_metrics_results' + iteration + '.csv'
    loss_results_name = str(model_dir+'/' + lr_name)
    metrics_test_df.to_csv(loss_results_name, index=False)
    np.savetxt(result_file+'/drugcell.predict', test_predict.cpu().numpy(),'%.4e')

# %% [markdown]
# ## RUN TRAIN

# %%
torch.cuda.empty_cache()
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
#print(train_data_file)
train_data, feature_dict, cell2id_mapping, drug2id_mapping = prepare_train_data(train_data_file, 
                                                                  test_data_file, cell2id, drug2id)
#print(train_data)
gene2id_mapping = load_mapping(gene2id)
modeldir = output_dir
cell_features = np.genfromtxt(genotype, delimiter=',')
drug_features = np.genfromtxt(fingerprint, delimiter=',')

num_cells = len(cell2id_mapping)
num_drugs = len(drug2id_mapping)
num_genes = len(gene2id_mapping)
drug_dim = len(drug_features[0,:])

# load ontology
dG, root, term_size_map, term_direct_gene_map = load_ontology(onto, gene2id_mapping)

# load the number of hiddens #######
num_hiddens_genotype = genotype_hiddens

num_hiddens_drug = list(map(int, drug_hiddens.split(',')))

num_hiddens_final = final_hiddens
#####################################

CUDA_ID = CUDA_ID

train_model(root, term_size_map, term_direct_gene_map, dG, 
            train_data, num_genes, drug_dim, modeldir, epochs,
            batch_size, learning_rate, num_hiddens_genotype, num_hiddens_drug, 
            num_hiddens_final, cell_features, drug_features)
#term_size_map
# Out:
# ../CCLE/drugcell_train.txt ../CCLE/drugcell_test.txt ../CCLE/cell2ind.txt ../CCLE/drug2ind.txt
# Total number of cell lines = 411
# Total number of drugs = 24
# There are 2983 genes
# There are 1 roots: GO:0008150
# There are 2086 terms
# There are 1 connected componenets
# INFO:DrugCell:	 **** TRAINING ****   Epoch [1/3], loss: 8.76658. This took 93.5 secs.
# INFO:DrugCell:	 **** TEST ****   Epoch [1/3], loss: 23.77550. This took 112.6 secs.
# INFO:DrugCell:	 **** TRAINING ****   Epoch [2/3], loss: 8.69690. This took 90.4 secs.
# INFO:DrugCell:	 **** TEST ****   Epoch [2/3], loss: 23.57244. This took 108.6 secs.
# INFO:DrugCell:	 **** TRAINING ****   Epoch [3/3], loss: 8.62723. This took 88.5 secs.
# INFO:DrugCell:	 **** TEST ****   Epoch [3/3], loss: 23.36594. This took 106.6 secs.
# Best performed model (epoch)	2
# {'test_loss': 23.36593969166279, 'test_pcc': 0.8255412578582764, 'test_MSE': 0.6846066117286682, 'test_r2': -6315309.0, 'test_scc': 1.0}
# {'test_loss': 23.36593969166279,
#  'test_pcc': 0.8255412578582764,
#  'test_MSE': 0.6846066117286682,
#  'test_r2': -6315309.0,
#  'test_scc': 1.0}

# %% [markdown]
# ## RESULTS between training and validation

# %%
#train_val_loss_df = pd.read_csv(lr_name)
#train_val_loss_df

# %% [markdown]
# ## Plots
#
# ### Training loss curve

# %%
## Plot of Epoch train loss
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="train_loss",
                data=train_val_loss_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 ## Plot of Epoch train loss
#       2 sns.set(style='whitegrid')
#       3 sns.lineplot(x="epoch",
#       4                 y="train_loss",
# ----> 5                 data=train_val_loss_df)
#
# NameError: name 'train_val_loss_df' is not defined

# %% [markdown]
# ## validation loss curve

# %%
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="test_loss",
                data=train_val_loss_df)
plt.ylabel('val_loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 sns.set(style='whitegrid')
#       2 sns.lineplot(x="epoch",
#       3                 y="test_loss",
# ----> 4                 data=train_val_loss_df)
#       5 plt.ylabel('val_loss')
#
# NameError: name 'train_val_loss_df' is not defined

# %% [markdown]
# ## Train Pearsons CC

# %%
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="train_corr",
                data=train_val_loss_df)
plt.ylabel('Train Pearsons CC')
#train_val_loss_df

# %% [markdown]
# ## Validation Pearsons CC

# %%
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="test_corr",
                data=train_val_loss_df)
plt.ylabel('validation Pearsons CC')

# %% [markdown]
# ## Train spearmen rank C

# %%
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="train_scc",
                data=train_val_loss_df)
plt.ylabel('Train spearmen rank C')
#train_val_loss_df

# %% [markdown]
# ## Validation spearmen rank C

# %%
sns.set(style='whitegrid')
sns.lineplot(x="epoch",
                y="test_scc",
                data=train_val_loss_df)
plt.ylabel('validation spearmen rank C')
#train_val_loss_df

# %%
mean_train_pcc = train_val_loss_df.train_corr.mean()
print("Train mean pearson corr \t%.6f" % (mean_train_pcc))

# %%
mean_test_pcc = train_val_loss_df.test_corr.mean()
print("Test mean pearson corr \t%.6f" % (mean_test_pcc))

# %%
mean_train_scc = train_val_loss_df.train_scc.mean()

print("Test train spearmen corr \t%.6f" % (mean_train_scc))

# %%
mean_test_scc = train_val_loss_df.test_scc.mean()
print("Test test spearmen corr \t%.6f" % (mean_test_scc))

# %% [markdown]
# ## RUN INFERENCE

# %%
cell_features = np.genfromtxt(genotype, delimiter=',')
drug_features = np.genfromtxt(fingerprint, delimiter=',')
num_cells = len(cell2id)
num_drugs = len(drug2id)
num_genes = len(gene2id)
drug_dim = len(drug_features[0,:])
#output_dir = params['output_dir']
model_trained_path = 'NOTEBOOK/model_final.pt'
predict_data = prepare_predict_data(test_data_file, cell2id, drug2id)
# Out:
# Total number of cell lines = 411
# Total number of drugs = 24

# %% [markdown]
# ## INFERENCE RESULT FROM TRAINED RESULT

# %%
print(drug_dim)
#predict_dcell(predict_data, num_genes, drug_dim, model_trained_path, hidden, batch_size,
#            result, cell_features, drug_features, CUDA_ID, output_dir)

# %% [markdown]
# ## INFERENCE RESULT FROM PRE-TRAINED MODEL FROM IDEKARLAB

# %%
cell_features = np.genfromtxt(genotype, delimiter=',')
drug_features = np.genfromtxt(fingerprint, delimiter=',')
num_cells = len(cell2id)
num_drugs = len(drug2id)
num_genes = len(gene2id)
drug_dim = len(drug_features[0,:])
#output_dir = params['output_dir']
model_trained_path = 'model_final.pt'
predict_data = prepare_predict_data(test_data_file, cell2id, drug2id)
predict_data
#predict_dcell(predict_data, num_genes, drug_dim, model_trained_path, hidden, batch_size,
#            result, cell_features, drug_features, CUDA_ID, output_dir)
# Out:
# Total number of cell lines = 411
# Total number of drugs = 24
# (tensor([[  0.,  21.],
#          [  1.,   0.],
#          [  1.,   4.],
#          ...,
#          [410.,   4.],
#          [410.,   7.],
#          [410.,  22.]]),
#  tensor([[0.8148],
#          [0.8126],
#          [0.4573],
#          [0.4997],
#          [0.7675],
#          [0.4433],
#          [0.8721],
#          [0.7955],
#          [0.7903],
#          [0.8935],
#          [0.7613],
#          [0.7959],
#          [0.8260],
#          [0.9244],
#          [0.4730],
#          [0.9191],
#          [0.8211],
#          [0.9359],
#          [0.8892],
#          [0.8452],
#          [0.6969],
#          [0.8997],
#          [0.5141],
#          [0.9252],
#          [0.8562],
#          [0.8477],
#          [1.0000],
#          [0.4335],
#          [0.8370],
#          [0.9478],
#          [0.9332],
#          [0.9241],
#          [0.7940],
#          [0.6029],
#          [0.7139],
#          [0.5935],
#          [0.7085],
#          [0.9660],
#          [0.9012],
#          [0.2722],
#          [0.9527],
#          [0.4557],
#          [0.8250],
#          [0.8950],
#          [0.4876],
#          [0.7888],
#          [0.7641],
#          [0.6534],
#          [0.9904],
#          [0.9333],
#          [0.7537],
#          [0.9372],
#          [0.9884],
#          [0.9022],
#          [0.8910],
#          [0.2615],
#          [0.3785],
#          [0.7665],
#          [0.5943],
#          [0.9283],
#          [0.8238],
#          [0.5041],
#          [0.6022],
#          [0.7699],
#          [0.7899],
#          [0.6179],
#          [0.9872],
#          [0.9453],
#          [0.8636],
#          [0.9912],
#          [0.7533],
#          [0.7133],
#          [0.6643],
#          [0.4047],
#          [0.6888],
#          [0.7082],
#          [0.7348],
#          [0.6660],
#          [0.8022],
#          [0.9126],
#          [0.9426],
#          [0.4981],
#          [0.8327],
#          [0.9750],
#          [0.7054],
#          [0.5137],
#          [0.5671],
#          [0.9201],
#          [0.8093],
#          [0.8352],
#          [0.7234],
#          [0.9159],
#          [0.9925],
#          [0.7912],
#          [0.9701],
#          [0.3488],
#          [0.8331],
#          [0.9650],
#          [0.6526],
#          [0.8677],
#          [0.6111],
#          [0.9516],
#          [0.7942],
#          [0.8191],
#          [0.8036],
#          [0.6477],
#          [0.7882],
#          [0.8717],
#          [0.9719],
#          [0.8172],
#          [0.8700],
#          [0.8223],
#          [0.8245],
#          [0.9379],
#          [0.7402],
#          [0.4300],
#          [0.7072],
#          [0.6113],
#          [0.7899],
#          [0.8034],
#          [0.9317],
#          [0.9204],
#          [0.9408],
#          [0.9396],
#          [0.9220],
#          [0.8454],
#          [1.0000],
#          [0.9255],
#          [0.8123],
#          [0.4218],
#          [0.9216],
#          [0.8405],
#          [0.9305],
#          [0.7632],
#          [0.6173],
#          [0.8590],
#          [0.8543],
#          [0.5712],
#          [0.4713],
#          [0.6910],
#          [0.8325],
#          [0.4060],
#          [0.3624],
#          [0.8793],
#          [0.6205],
#          [1.0000],
#          [0.8205],
#          [0.7814],
#          [0.4623],
#          [0.6556],
#          [0.9809],
#          [0.9452],
#          [0.5062],
#          [0.7415],
#          [0.8776],
#          [0.5927],
#          [0.9405],
#          [0.7986],
#          [0.5380],
#          [0.6692],
#          [0.8253],
#          [0.5152],
#          [1.0000],
#          [0.7293],
#          [0.7153],
#          [0.7353],
#          [0.3950],
#          [0.9055],
#          [0.8634],
#          [0.9380],
#          [0.9086],
#          [0.7930],
#          [0.7308],
#          [0.9456],
#          [0.8765],
#          [0.7956],
#          [0.9233],
#          [0.7863],
#          [0.8011],
#          [0.8172],
#          [0.7001],
#          [0.4185],
#          [0.9125],
#          [0.6570],
#          [0.7844],
#          [0.7858],
#          [0.9843],
#          [0.8435],
#          [0.9186],
#          [0.8668],
#          [0.8239],
#          [0.9545],
#          [0.9137],
#          [0.8673],
#          [0.3455],
#          [0.9118],
#          [0.9671],
#          [1.0000],
#          [0.8423],
#          [0.9559],
#          [0.8292],
#          [0.7504],
#          [0.8152],
#          [0.8198],
#          [0.8615],
#          [0.9186],
#          [0.5795],
#          [0.7996],
#          [0.9344],
#          [0.9243],
#          [0.9003],
#          [0.8143],
#          [0.8735],
#          [0.8516],
#          [0.6079],
#          [0.5412],
#          [0.7910],
#          [0.8518],
#          [0.7682],
#          [0.9133],
#          [0.9532],
#          [0.8165],
#          [0.8100],
#          [0.7876],
#          [0.8594],
#          [0.7218],
#          [0.8076],
#          [0.6264],
#          [0.5856],
#          [0.7098],
#          [0.4804],
#          [0.7762],
#          [0.4751],
#          [0.9672],
#          [0.8186],
#          [0.8975],
#          [0.8276],
#          [0.8260],
#          [0.5218],
#          [0.5575],
#          [0.8201],
#          [0.4780],
#          [0.8878],
#          [0.8197],
#          [0.6192],
#          [0.9465],
#          [0.4269],
#          [0.9221],
#          [0.8902],
#          [0.8322],
#          [0.7326],
#          [0.9540],
#          [0.8783],
#          [0.7250],
#          [0.5515],
#          [0.6415],
#          [0.4396],
#          [0.7871],
#          [0.8348],
#          [0.7845],
#          [0.7992],
#          [0.7936],
#          [0.9540],
#          [0.8905],
#          [0.7058],
#          [0.9736],
#          [0.8609],
#          [0.8761],
#          [0.8997],
#          [0.7274],
#          [0.9644],
#          [0.9152],
#          [0.7017],
#          [0.9395],
#          [0.5845],
#          [0.4550],
#          [0.4118],
#          [0.7396],
#          [0.8449],
#          [0.7417],
#          [0.7829],
#          [0.7851],
#          [0.6798],
#          [0.8225],
#          [0.8251],
#          [0.8033],
#          [0.9366],
#          [0.9792],
#          [0.7241],
#          [0.9332],
#          [0.8361],
#          [0.7992],
#          [0.8951],
#          [0.9346],
#          [0.8332],
#          [0.8410],
#          [0.8525],
#          [0.8178],
#          [0.9630],
#          [0.8423],
#          [0.7717],
#          [0.5567],
#          [0.9319],
#          [0.6527],
#          [0.8712],
#          [0.7556],
#          [0.8579],
#          [0.6322],
#          [0.8229],
#          [0.4641],
#          [0.9711],
#          [0.9284],
#          [0.8087],
#          [0.9339],
#          [0.7637],
#          [0.8964],
#          [0.9120],
#          [0.6088],
#          [0.8417],
#          [0.4720],
#          [0.8412],
#          [0.7995],
#          [0.7991],
#          [0.7565],
#          [0.7682],
#          [0.9072],
#          [0.9882],
#          [0.8102],
#          [0.9708],
#          [0.8360],
#          [0.7900],
#          [0.6967],
#          [0.9255],
#          [0.8131],
#          [0.7416],
#          [0.8053],
#          [0.9394],
#          [0.9778],
#          [0.8771],
#          [0.8325],
#          [0.8626],
#          [0.7989],
#          [0.8331],
#          [0.9661],
#          [0.0822],
#          [0.7328],
#          [0.9743],
#          [0.9461],
#          [0.4552],
#          [0.9209],
#          [0.8158],
#          [0.9117],
#          [0.6215],
#          [0.5740],
#          [0.9368],
#          [0.8618],
#          [0.7727],
#          [0.8247],
#          [0.9352],
#          [0.8224],
#          [0.5286],
#          [0.8240],
#          [0.8160],
#          [0.4362],
#          [0.5432],
#          [0.9334],
#          [0.5728],
#          [0.6731],
#          [0.8843],
#          [0.8420],
#          [0.3896],
#          [0.7487],
#          [0.8106],
#          [0.6714],
#          [0.8028],
#          [0.9021],
#          [0.8751],
#          [0.5655],
#          [0.8528],
#          [0.8481],
#          [0.9665],
#          [0.5628],
#          [0.5189],
#          [0.7062],
#          [0.9924],
#          [0.7797],
#          [0.6875],
#          [0.4012],
#          [0.8092],
#          [0.9706],
#          [0.8786],
#          [0.4795],
#          [0.5763],
#          [0.7142],
#          [0.9253],
#          [0.7052],
#          [0.9609],
#          [0.6207],
#          [0.8622],
#          [0.7936],
#          [0.8843],
#          [0.5741],
#          [0.9403],
#          [0.8343],
#          [0.4801],
#          [0.9682],
#          [0.8685],
#          [0.8219],
#          [0.5802],
#          [0.7440],
#          [0.6782],
#          [0.9063],
#          [0.9449],
#          [0.5639],
#          [0.8801],
#          [0.9357],
#          [0.9436],
#          [0.8358],
#          [0.8690],
#          [0.9330],
#          [0.9019],
#          [0.7928],
#          [0.6943],
#          [0.9537],
#          [0.5251],
#          [0.9000],
#          [0.9719],
#          [0.8564],
#          [0.6176],
#          [0.7719],
#          [0.9610],
#          [0.7835],
#          [0.8194],
#          [0.7580],
#          [0.8361],
#          [0.6321],
#          [0.9523],
#          [0.8869],
#          [0.4643],
#          [0.2995],
#          [0.9207],
#          [0.9684],
#          [0.8081],
#          [0.9130],
#          [0.8308],
#          [0.8292],
#          [0.4156],
#          [0.8412],
#          [0.8214],
#          [0.8308],
#          [0.8359],
#          [0.8420],
#          [0.7377],
#          [0.8592],
#          [0.9344],
#          [0.9134],
#          [0.9904],
#          [0.8325],
#          [0.8115],
#          [0.6716],
#          [0.8259],
#          [0.7722],
#          [0.7834],
#          [0.8004],
#          [0.4771],
#          [0.6645],
#          [0.7769],
#          [0.4619],
#          [0.7208],
#          [0.8772],
#          [0.8780],
#          [0.8875],
#          [0.9264],
#          [0.8150],
#          [0.5858],
#          [0.8255],
#          [0.8673],
#          [0.5824],
#          [0.7655],
#          [0.9906],
#          [0.8699],
#          [0.6147],
#          [0.6176],
#          [0.9409],
#          [0.9543],
#          [0.8070],
#          [0.3464],
#          [0.6713],
#          [0.8609],
#          [0.8583],
#          [0.8174],
#          [0.8575],
#          [0.8074],
#          [0.3189],
#          [0.9399],
#          [0.9886],
#          [0.6855],
#          [0.3968],
#          [0.9772],
#          [0.8230],
#          [0.6080],
#          [0.8718],
#          [0.8317],
#          [0.9545],
#          [0.9581],
#          [0.9141],
#          [0.9018],
#          [0.7923],
#          [0.7841],
#          [0.8411],
#          [0.4299],
#          [0.3869],
#          [0.7301],
#          [0.8737],
#          [0.9020],
#          [0.8690],
#          [0.7921],
#          [0.7968],
#          [0.8687],
#          [0.7927],
#          [0.9907],
#          [0.7543],
#          [0.9588],
#          [0.8292],
#          [0.9729],
#          [1.0000],
#          [0.9537],
#          [0.9842],
#          [0.7381],
#          [0.8791],
#          [0.7557],
#          [0.8447],
#          [0.8534],
#          [0.8492],
#          [0.6851],
#          [0.8525],
#          [0.7730],
#          [0.9897],
#          [0.9179],
#          [0.5760],
#          [0.3474],
#          [0.8548],
#          [0.9237],
#          [0.8501],
#          [0.3295],
#          [0.7208],
#          [0.7332],
#          [0.9969],
#          [0.8925],
#          [0.8438],
#          [0.8486],
#          [0.8430],
#          [0.8319],
#          [0.6188],
#          [0.9519],
#          [0.7927],
#          [0.8261],
#          [0.7426],
#          [0.3844],
#          [0.8308],
#          [0.5546],
#          [0.9798],
#          [0.8961],
#          [0.7072],
#          [0.5149],
#          [0.6097],
#          [0.2418],
#          [0.5251],
#          [0.8446],
#          [0.8660],
#          [0.8425],
#          [0.4470],
#          [0.4644],
#          [0.7995],
#          [0.7903],
#          [0.9681],
#          [0.9596],
#          [0.6329],
#          [0.4361],
#          [0.9781],
#          [0.4707],
#          [0.9944],
#          [0.8332],
#          [0.8673],
#          [0.6773],
#          [0.9276],
#          [0.7610],
#          [0.8568],
#          [0.6868],
#          [0.8935],
#          [0.8412],
#          [0.9720],
#          [0.9590],
#          [0.7980],
#          [0.9854],
#          [0.8333],
#          [0.9426],
#          [0.6093],
#          [0.9673],
#          [0.9554],
#          [0.7861],
#          [0.9460],
#          [0.9714],
#          [0.8177],
#          [0.8656],
#          [0.9717],
#          [0.7929],
#          [0.7851],
#          [0.8714],
#          [0.9574],
#          [0.8749],
#          [0.7226],
#          [0.8101],
#          [0.8484],
#          [0.5085],
#          [0.3265],
#          [0.5043],
#          [0.8758],
#          [0.3711],
#          [0.2753],
#          [0.6054],
#          [0.4840],
#          [0.2959],
#          [0.9074],
#          [0.7218],
#          [0.9563],
#          [0.7803],
#          [0.9798],
#          [0.5945],
#          [0.7783],
#          [0.5266],
#          [0.8446],
#          [0.5826],
#          [0.7528],
#          [0.9105],
#          [0.8305],
#          [0.8990],
#          [0.6063],
#          [0.8380],
#          [0.8915],
#          [0.8752],
#          [0.5080],
#          [0.8635],
#          [0.7727],
#          [0.8569],
#          [0.3732],
#          [0.4218],
#          [0.7111],
#          [0.7307],
#          [0.6552],
#          [0.9218],
#          [0.7804],
#          [0.7459],
#          [0.3688],
#          [0.4951],
#          [0.9515],
#          [0.9787],
#          [0.9555],
#          [0.8761],
#          [0.8334],
#          [0.7833],
#          [0.8068],
#          [0.6106],
#          [0.7274],
#          [0.8011],
#          [0.8401],
#          [0.6335],
#          [0.9475],
#          [0.7874],
#          [0.8239],
#          [0.9809],
#          [0.2354],
#          [0.8170],
#          [0.7658],
#          [0.8073],
#          [0.8343],
#          [1.0000],
#          [0.8230],
#          [0.9794],
#          [0.8067],
#          [0.4131],
#          [0.5266],
#          [0.8428],
#          [0.9677],
#          [0.9472],
#          [0.8702],
#          [1.0000],
#          [0.5807],
#          [0.7900],
#          [0.9741],
#          [0.8143],
#          [0.7805],
#          [0.9767],
#          [0.7610],
#          [0.9545],
#          [0.8002],
#          [0.7801],
#          [0.5475],
#          [0.8245],
#          [0.9022],
#          [0.5541],
#          [0.9888],
#          [0.8146],
#          [0.8795],
#          [0.8944],
#          [0.8593],
#          [0.5549],
#          [0.7404],
#          [0.6298],
#          [0.7837],
#          [0.8612],
#          [0.5580],
#          [0.8550],
#          [0.8500],
#          [0.9091],
#          [0.5004],
#          [0.8012],
#          [0.3992],
#          [0.8490],
#          [0.9787],
#          [0.8499],
#          [0.9444],
#          [0.7334],
#          [0.8253],
#          [0.5071],
#          [0.7172],
#          [0.7818],
#          [0.4029],
#          [0.6764],
#          [0.8671],
#          [0.9480],
#          [0.7075],
#          [0.7421],
#          [0.8268],
#          [0.8513],
#          [0.9629],
#          [0.9704],
#          [0.8366],
#          [0.8785],
#          [0.6028],
#          [0.8422],
#          [0.9699],
#          [0.7770],
#          [0.9144],
#          [0.9536],
#          [0.8705],
#          [0.8136],
#          [0.4747],
#          [0.8553],
#          [0.7788],
#          [0.6258],
#          [0.7957],
#          [0.8114],
#          [0.8463],
#          [0.9830],
#          [0.9540],
#          [0.7611],
#          [0.4208],
#          [0.8332],
#          [0.9479],
#          [0.7873],
#          [0.6444],
#          [0.7532],
#          [0.8223],
#          [0.8975],
#          [0.7996],
#          [0.9587],
#          [0.8384],
#          [0.9285],
#          [0.3788],
#          [0.5926],
#          [0.9171],
#          [0.8806],
#          [0.6913],
#          [0.8042],
#          [0.7352],
#          [0.7691],
#          [0.8637],
#          [0.6337],
#          [0.8118],
#          [0.8073],
#          [0.3835],
#          [0.8689],
#          [0.9014],
#          [0.9257],
#          [0.8434],
#          [0.9489],
#          [0.8137],
#          [0.8314],
#          [0.8612],
#          [0.9578],
#          [0.9233],
#          [0.8675],
#          [0.5389],
#          [0.7268],
#          [0.8073],
#          [0.8352],
#          [0.5259],
#          [0.5041],
#          [0.4667],
#          [0.8794],
#          [0.8343],
#          [0.9310],
#          [0.9407],
#          [0.6616],
#          [0.9323],
#          [0.5715],
#          [0.7952],
#          [0.5574],
#          [0.7445],
#          [0.7044],
#          [0.9425],
#          [0.8864],
#          [0.5775],
#          [0.9057],
#          [0.9922],
#          [0.8072],
#          [0.8315],
#          [0.7843],
#          [0.9876],
#          [0.8631],
#          [0.5926],
#          [0.7452],
#          [0.9394],
#          [0.7913],
#          [0.9590],
#          [0.8004],
#          [0.9228],
#          [0.7581],
#          [0.8625],
#          [0.9182],
#          [0.7613],
#          [0.7749],
#          [0.8116],
#          [0.5452],
#          [0.5928],
#          [0.8386],
#          [0.7518],
#          [0.8238],
#          [0.9747],
#          [0.9519],
#          [0.8326],
#          [0.7912],
#          [0.7665],
#          [0.8208],
#          [0.6282],
#          [0.8372],
#          [0.7561],
#          [0.8655],
#          [0.8203],
#          [0.9098],
#          [0.6533],
#          [0.8518],
#          [0.4984],
#          [0.7530],
#          [0.5066],
#          [0.9090],
#          [0.5680],
#          [0.3162],
#          [0.9843],
#          [0.4650],
#          [0.5995],
#          [0.9033],
#          [0.5881],
#          [0.8073],
#          [0.8422],
#          [0.8053],
#          [0.8991],
#          [0.9491],
#          [0.9857],
#          [0.3735],
#          [0.9314],
#          [0.9458],
#          [0.8212],
#          [0.9929],
#          [0.8317],
#          [0.9301],
#          [0.8223],
#          [0.8245],
#          [0.9286],
#          [0.8368],
#          [0.8099],
#          [0.8532],
#          [0.8472],
#          [0.9305],
#          [0.9399],
#          [0.8057],
#          [0.9406],
#          [0.9675],
#          [0.6636],
#          [0.7091],
#          [0.6619],
#          [0.9661],
#          [0.8909],
#          [0.8986],
#          [0.8727],
#          [0.9562],
#          [0.9721],
#          [0.8343],
#          [0.7693],
#          [0.8625],
#          [0.8198],
#          [0.9529],
#          [0.7498],
#          [0.7155],
#          [0.9423],
#          [0.7888],
#          [0.8053],
#          [0.8194],
#          [0.4455],
#          [0.7934],
#          [0.9561],
#          [0.7579],
#          [0.8486],
#          [0.7809],
#          [0.7741],
#          [0.8416],
#          [0.9806],
#          [0.7456],
#          [0.7692],
#          [0.6647],
#          [0.8083],
#          [0.9798],
#          [0.7817],
#          [0.9971],
#          [0.9756],
#          [0.1548],
#          [0.8402],
#          [0.4392],
#          [0.8605],
#          [0.5227],
#          [0.9950],
#          [0.8516],
#          [0.5638],
#          [0.8762],
#          [0.8045],
#          [0.7707],
#          [1.0000],
#          [0.7114],
#          [0.9216],
#          [0.8483],
#          [0.9028],
#          [0.6643],
#          [0.9519],
#          [0.6967],
#          [0.9659],
#          [0.3855],
#          [0.6438],
#          [0.9371],
#          [0.9529],
#          [0.8819]]),
#  {'ACH-000956;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [0,
#    21],
#   'ACH-000323;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [1, 0],
#   'ACH-000323;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [1,
#    4],
#   'ACH-000905;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [2,
#    23],
#   'ACH-000973;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [3, 0],
#   'ACH-000070;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [4,
#    23],
#   'ACH-000070;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [4, 5],
#   'ACH-000070;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [4, 6],
#   'ACH-000411;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [5, 1],
#   'ACH-000411;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [5, 5],
#   'ACH-000411;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [5, 14],
#   'ACH-000649;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [6,
#    12],
#   'ACH-000649;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [6,
#    16],
#   'ACH-000649;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [6,
#    22],
#   'ACH-001306;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [7, 2],
#   'ACH-001306;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [7,
#    3],
#   'ACH-001306;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [7, 7],
#   'ACH-001306;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [7, 15],
#   'ACH-001306;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [7,
#    16],
#   'ACH-001307;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [8, 11],
#   'ACH-001307;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [8,
#    12],
#   'ACH-000558;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [10, 0],
#   'ACH-000558;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [10, 2],
#   'ACH-000558;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [10, 9],
#   'ACH-000201;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [11, 5],
#   'ACH-000788;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [12, 5],
#   'ACH-000740;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [13,
#    7],
#   'ACH-000740;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [13,
#    8],
#   'ACH-000740;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [13, 15],
#   'ACH-000740;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [13,
#    17],
#   'ACH-000740;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [13, 19],
#   'ACH-000657;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [14, 5],
#   'ACH-000657;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [14,
#    22],
#   'ACH-000219;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [15, 9],
#   'ACH-000219;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [15,
#    13],
#   'ACH-000219;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [15,
#    20],
#   'ACH-000681;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [16, 0],
#   'ACH-000681;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [16,
#    22],
#   'ACH-000052;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [17, 5],
#   'ACH-000052;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [17,
#    8],
#   'ACH-000052;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [17,
#    22],
#   'ACH-000046;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [18, 2],
#   'ACH-000046;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [18,
#    17],
#   'ACH-000046;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [18, 19],
#   'ACH-000838;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [20,
#    4],
#   'ACH-000838;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [20, 9],
#   'ACH-000838;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [20, 19],
#   'ACH-000222;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [21, 9],
#   'ACH-000248;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [22, 9],
#   'ACH-000456;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [23, 5],
#   'ACH-000080;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [24, 9],
#   'ACH-000792;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [25, 5],
#   'ACH-000792;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [25,
#    10],
#   'ACH-000792;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [25,
#    17],
#   'ACH-000245;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [26, 0],
#   'ACH-000245;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [26,
#    8],
#   'ACH-000402;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [27, 2],
#   'ACH-000402;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [27,
#    7],
#   'ACH-000402;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [27,
#    20],
#   'ACH-000536;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [28,
#    10],
#   'ACH-000536;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [28,
#    22],
#   'ACH-000927;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [29,
#    21],
#   'ACH-000535;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [31,
#    4],
#   'ACH-000535;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [31,
#    13],
#   'ACH-000009;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [32, 1],
#   'ACH-000009;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [32,
#    8],
#   'ACH-000009;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [32,
#    16],
#   'ACH-000580;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [33,
#    7],
#   'ACH-000580;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [33,
#    16],
#   'ACH-000580;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [33,
#    21],
#   'ACH-000826;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [34, 9],
#   'ACH-000826;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [34,
#    21],
#   'ACH-000857;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [36,
#    4],
#   'ACH-000857;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [36,
#    8],
#   'ACH-000857;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [36,
#    12],
#   'ACH-000511;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [37, 6],
#   'ACH-000392;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [38, 9],
#   'ACH-000264;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [39,
#    13],
#   'ACH-000264;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [39, 14],
#   'ACH-000264;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [39,
#    21],
#   'ACH-000783;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [40, 1],
#   'ACH-000783;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [40,
#    8],
#   'ACH-000783;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [40,
#    12],
#   'ACH-000783;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [40, 15],
#   'ACH-000107;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [41, 0],
#   'ACH-000107;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [41, 2],
#   'ACH-000107;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [41, 6],
#   'ACH-000107;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [41, 11],
#   'ACH-000107;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [41,
#    12],
#   'ACH-000107;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [41, 14],
#   'ACH-000464;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [42,
#    4],
#   'ACH-000464;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [42, 9],
#   'ACH-000963;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [43,
#    22],
#   'ACH-000120;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [44, 1],
#   'ACH-000120;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [44,
#    3],
#   'ACH-000120;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [44, 6],
#   'ACH-000120;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [44, 19],
#   'ACH-000687;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [45, 15],
#   'ACH-000253;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [46, 11],
#   'ACH-000253;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [46, 19],
#   'ACH-000202;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [47,
#    23],
#   'ACH-000202;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [47, 5],
#   'ACH-000202;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [47, 14],
#   'ACH-000350;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [48, 0],
#   'ACH-000350;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [48, 1],
#   'ACH-000350;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [48, 6],
#   'ACH-000350;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [48,
#    12],
#   'ACH-000350;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [48, 14],
#   'ACH-000805;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [49, 5],
#   'ACH-000805;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [49,
#    13],
#   'ACH-000805;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [49, 14],
#   'ACH-000805;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [49, 15],
#   'ACH-000805;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [49, 19],
#   'ACH-000582;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [50, 1],
#   'ACH-000582;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [50, 5],
#   'ACH-000582;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [50,
#    8],
#   'ACH-000161;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [51, 6],
#   'ACH-000161;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [51,
#    8],
#   'ACH-000161;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [51,
#    12],
#   'ACH-000662;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [52, 0],
#   'ACH-000662;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [52, 1],
#   'ACH-000662;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [52,
#    22],
#   'ACH-000256;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [53,
#    18],
#   'ACH-000211;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [54, 9],
#   'ACH-000863;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [55,
#    21],
#   'ACH-000863;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [55,
#    17],
#   'ACH-000863;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [55,
#    22],
#   'ACH-000207;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [56, 0],
#   'ACH-000207;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [56, 6],
#   'ACH-000244;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [57,
#    8],
#   'ACH-000244;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [57,
#    18],
#   'ACH-000530;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [58, 6],
#   'ACH-000530;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [58,
#    21],
#   'ACH-000056;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [59,
#    17],
#   'ACH-000925;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [60, 9],
#   'ACH-000877;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [61, 5],
#   'ACH-000877;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [61,
#    16],
#   'ACH-000563;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [62,
#    23],
#   'ACH-000563;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [62, 19],
#   'ACH-000435;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [63,
#    23],
#   'ACH-000435;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [63, 19],
#   'ACH-000330;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [64, 2],
#   'ACH-000330;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [64,
#    8],
#   'ACH-000308;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [65,
#    18],
#   'ACH-000936;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [66,
#    23],
#   'ACH-000936;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [66,
#    7],
#   'ACH-000936;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [66, 14],
#   'ACH-000936;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [66,
#    18],
#   'ACH-000295;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [67,
#    23],
#   'ACH-000295;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [67, 19],
#   'ACH-000978;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [68,
#    7],
#   'ACH-000978;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [68, 9],
#   'ACH-000906;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [69,
#    4],
#   'ACH-000913;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [70,
#    13],
#   'ACH-000913;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [70, 15],
#   'ACH-000487;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [71, 0],
#   'ACH-000487;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [71,
#    7],
#   'ACH-000487;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [71,
#    10],
#   'ACH-000487;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [71,
#    12],
#   'ACH-000487;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [71, 14],
#   'ACH-000487;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [71,
#    21],
#   'ACH-000846;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [72, 2],
#   'ACH-000846;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [72,
#    3],
#   'ACH-000846;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [72, 9],
#   'ACH-000846;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [72,
#    21],
#   'ACH-000846;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [72,
#    18],
#   'ACH-000633;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [73, 2],
#   'ACH-000633;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [73, 5],
#   'ACH-000574;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [74,
#    3],
#   'ACH-000096;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [76, 15],
#   'ACH-000096;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [76,
#    21],
#   'ACH-000096;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [76,
#    22],
#   'ACH-000375;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [77, 14],
#   'ACH-000098;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [78, 9],
#   'ACH-000738;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [79, 0],
#   'ACH-000738;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [79,
#    3],
#   'ACH-000738;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [79,
#    10],
#   'ACH-000738;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [79,
#    18],
#   'ACH-000738;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [79, 19],
#   'ACH-000835;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [80,
#    10],
#   'ACH-000835;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [80,
#    13],
#   'ACH-000756;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [81,
#    8],
#   'ACH-000756;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [81, 19],
#   'ACH-000102;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [82,
#    20],
#   'ACH-000073;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [83, 1],
#   'ACH-000073;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [83,
#    13],
#   'ACH-000389;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [84, 5],
#   'ACH-000389;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [84,
#    16],
#   'ACH-000389;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [84,
#    18],
#   'ACH-000843;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [85, 1],
#   'ACH-000843;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [85, 14],
#   'ACH-000111;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [86, 5],
#   'ACH-000111;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [86, 19],
#   'ACH-000699;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [87, 6],
#   'ACH-000699;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [87,
#    8],
#   'ACH-000878;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [88, 1],
#   'ACH-000878;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [88, 15],
#   'ACH-000878;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [88,
#    22],
#   'ACH-000930;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [89, 15],
#   'ACH-000930;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [89,
#    17],
#   'ACH-000624;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [90,
#    3],
#   'ACH-000624;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [90, 6],
#   'ACH-000150;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [92,
#    12],
#   'ACH-000066;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [93, 0],
#   'ACH-000066;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [93, 19],
#   'ACH-000667;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [94, 1],
#   'ACH-000668;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [96,
#    23],
#   'ACH-000668;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [96,
#    12],
#   'ACH-000562;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [97, 0],
#   'ACH-000562;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [97, 1],
#   'ACH-000562;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [97,
#    12],
#   'ACH-000012;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [98, 0],
#   'ACH-000012;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [98, 6],
#   'ACH-000012;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [98, 14],
#   'ACH-000971;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [99,
#    4],
#   'ACH-000971;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [99, 6],
#   'ACH-000997;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [100,
#    3],
#   'ACH-000997;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [100, 5],
#   'ACH-000997;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [100, 6],
#   'ACH-000997;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [100, 9],
#   'ACH-000997;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [100,
#    16],
#   'ACH-000190;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [101,
#    3],
#   'ACH-000190;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [101, 11],
#   'ACH-000190;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [101,
#    13],
#   'ACH-000190;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [101,
#    16],
#   'ACH-000643;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [102,
#    10],
#   'ACH-000972;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [103,
#    3],
#   'ACH-000972;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [103,
#    12],
#   'ACH-000972;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [103,
#    20],
#   'ACH-000954;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [104,
#    4],
#   'ACH-000954;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [104,
#    8],
#   'ACH-000954;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [104,
#    18],
#   'ACH-000941;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [105, 2],
#   'ACH-000941;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [105,
#    17],
#   'ACH-000996;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [106, 6],
#   'ACH-000996;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [106, 15],
#   'ACH-000946;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [107, 1],
#   'ACH-000946;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [107,
#    13],
#   'ACH-000994;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [108,
#    23],
#   'ACH-000994;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [108,
#    8],
#   'ACH-000994;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [108,
#    14],
#   'ACH-000984;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [109, 2],
#   'ACH-000984;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [109,
#    7],
#   'ACH-000984;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [109,
#    12],
#   'ACH-000005;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [110,
#    4],
#   'ACH-000005;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [110,
#    7],
#   'ACH-000005;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [110,
#    8],
#   'ACH-000005;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [110,
#    18],
#   'ACH-000625;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [111, 1],
#   'ACH-000625;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [111,
#    10],
#   'ACH-000625;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [111,
#    14],
#   'ACH-000625;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [111,
#    22],
#   'ACH-000739;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [112, 5],
#   'ACH-000739;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [112,
#    12],
#   'ACH-000542;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [113,
#    4],
#   'ACH-000542;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [113, 6],
#   'ACH-000542;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [113,
#    8],
#   'ACH-000542;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [113,
#    13],
#   'ACH-000542;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [113, 15],
#   'ACH-000542;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [113, 19],
#   'ACH-000847;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [114, 19],
#   'ACH-000847;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [114,
#    22],
#   'ACH-000061;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [115,
#    10],
#   'ACH-000061;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [115,
#    14],
#   'ACH-000061;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [115,
#    20],
#   'ACH-000061;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [115,
#    21],
#   'ACH-000393;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [116,
#    7],
#   'ACH-000393;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [116, 11],
#   'ACH-000393;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [116,
#    17],
#   'ACH-000721;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [117,
#    23],
#   'ACH-000721;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [117,
#    16],
#   'ACH-000721;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [117,
#    21],
#   'ACH-000931;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [118,
#    12],
#   'ACH-000613;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [119, 9],
#   'ACH-000613;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [119,
#    20],
#   'ACH-000270;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [120, 2],
#   'ACH-000270;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [120,
#    8],
#   'ACH-000270;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [120, 9],
#   'ACH-000270;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [120,
#    16],
#   'ACH-000270;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [120, 19],
#   'ACH-000094;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [121, 0],
#   'ACH-000094;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [121, 1],
#   'ACH-000094;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [121,
#    4],
#   'ACH-000094;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [121, 19],
#   'ACH-000131;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [122,
#    12],
#   'ACH-000131;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [122,
#    14],
#   'ACH-000131;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [122,
#    21],
#   'ACH-000131;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [122,
#    17],
#   'ACH-000014;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [123, 5],
#   'ACH-000014;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [123,
#    21],
#   'ACH-000148;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [124,
#    4],
#   'ACH-000148;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [124, 6],
#   'ACH-000148;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [124, 9],
#   'ACH-000148;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [124,
#    17],
#   'ACH-000067;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [125,
#    12],
#   'ACH-000799;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [126, 11],
#   'ACH-000133;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [127, 1],
#   'ACH-000133;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [127,
#    12],
#   'ACH-000133;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [127, 15],
#   'ACH-000133;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [127,
#    22],
#   'ACH-000616;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [128, 9],
#   'ACH-000178;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [129, 2],
#   'ACH-000274;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [130, 5],
#   'ACH-000274;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [130,
#    13],
#   'ACH-000801;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [131, 0],
#   'ACH-000801;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [131,
#    23],
#   'ACH-000801;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [131,
#    7],
#   'ACH-000801;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [131, 9],
#   'ACH-000814;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [132,
#    12],
#   'ACH-000814;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [132,
#    20],
#   'ACH-000814;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [132, 19],
#   'ACH-000814;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [132,
#    22],
#   'ACH-000632;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [133, 0],
#   'ACH-000632;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [133,
#    7],
#   'ACH-000632;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [133,
#    14],
#   'ACH-000632;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [133,
#    17],
#   'ACH-000472;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [134,
#    10],
#   'ACH-000472;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [134,
#    20],
#   'ACH-000054;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [136, 5],
#   'ACH-000547;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [137, 2],
#   'ACH-000547;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [137,
#    3],
# ...
#   'ACH-000312;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [339,
#    8],
#   'ACH-000312;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [339,
#    12],
#   'ACH-000366;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [340, 5],
#   'ACH-000366;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [340, 6],
#   'ACH-000366;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [340,
#    21],
#   'ACH-000341;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [341, 15],
#   'ACH-000149;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [342, 6],
#   'ACH-000149;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [342,
#    7],
#   'ACH-000811;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [343, 0],
#   'ACH-000811;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [343,
#    3],
#   'ACH-000811;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [343,
#    7],
#   'ACH-000974;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [344, 0],
#   'ACH-000974;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [344, 2],
#   'ACH-000974;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [344,
#    23],
#   'ACH-000974;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [344,
#    13],
#   'ACH-000974;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [344, 19],
#   'ACH-000932;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [345, 2],
#   'ACH-000932;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [345,
#    8],
#   'ACH-000483;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [346,
#    8],
#   'ACH-000483;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [346, 15],
#   'ACH-000478;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [347,
#    4],
#   'ACH-000478;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [347,
#    21],
#   'ACH-000478;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [347, 19],
#   'ACH-000221;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [348, 6],
#   'ACH-000493;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [349, 1],
#   'ACH-000493;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [349, 2],
#   'ACH-000420;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [350, 0],
#   'ACH-000420;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [350, 2],
#   'ACH-000420;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [350,
#    23],
#   'ACH-000422;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [351,
#    4],
#   'ACH-000422;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [351, 9],
#   'ACH-000967;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [352, 1],
#   'ACH-000967;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [352,
#    8],
#   'ACH-000967;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [352, 15],
#   'ACH-000967;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [352,
#    22],
#   'ACH-000553;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [353,
#    13],
#   'ACH-000553;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [353,
#    16],
#   'ACH-000553;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [353,
#    18],
#   'ACH-000553;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [353, 19],
#   'ACH-000114;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [354, 6],
#   'ACH-000271;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [355,
#    23],
#   'ACH-000271;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [355, 6],
#   'ACH-000271;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [355,
#    10],
#   'ACH-000271;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [355,
#    12],
#   'ACH-000271;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [355, 15],
#   'ACH-000365;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [356, 11],
#   'ACH-000611;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [357, 6],
#   'ACH-000611;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [357,
#    13],
#   'ACH-000656;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [358, 6],
#   'ACH-000656;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [358, 9],
#   'ACH-000656;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [358,
#    13],
#   'ACH-000656;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [358,
#    14],
#   'ACH-000656;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [358,
#    16],
#   'ACH-000652;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [359,
#    4],
#   'ACH-000652;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [359, 6],
#   'ACH-000652;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [359,
#    21],
#   'ACH-000226;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [360, 6],
#   'ACH-000226;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [360,
#    17],
#   'ACH-000953;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [361,
#    3],
#   'ACH-000953;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [361, 5],
#   'ACH-000437;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [362,
#    4],
#   'ACH-000437;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [362, 5],
#   'ACH-000437;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [362,
#    14],
#   'ACH-000437;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [362,
#    22],
#   'ACH-000890;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [363,
#    23],
#   'ACH-000890;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [363, 11],
#   'ACH-000890;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [363,
#    12],
#   'ACH-000890;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [363,
#    13],
#   'ACH-000418;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [364,
#    12],
#   'ACH-000236;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [365, 5],
#   'ACH-000236;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [365, 9],
#   'ACH-000236;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [365,
#    14],
#   'ACH-000236;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [365,
#    20],
#   'ACH-000236;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [365,
#    18],
#   'ACH-000677;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [366, 2],
#   'ACH-000677;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [366, 5],
#   'ACH-000677;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [366,
#    8],
#   'ACH-000958;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [369,
#    8],
#   'ACH-000958;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [369,
#    16],
#   'ACH-000842;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [370, 2],
#   'ACH-000842;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [370,
#    23],
#   'ACH-000842;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [370,
#    14],
#   'ACH-000163;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [371,
#    4],
#   'ACH-000163;Cc1cn(-c2cc(NC(=O)c3ccc(C)c(Nc4nccc(-c5cccnc5)n4)c3)cc(C(F)(F)F)c2)cn1': [371,
#    10],
#   'ACH-000163;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [371,
#    21],
#   'ACH-000669;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [374,
#    4],
#   'ACH-000669;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [374,
#    7],
#   'ACH-000669;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [374, 9],
#   'ACH-000669;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [374,
#    22],
#   'ACH-000018;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [375,
#    8],
#   'ACH-000018;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [375,
#    16],
#   'ACH-000018;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [375,
#    17],
#   'ACH-000813;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [376,
#    4],
#   'ACH-000147;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [377, 6],
#   'ACH-000147;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [377,
#    13],
#   'ACH-000147;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [377, 19],
#   'ACH-000147;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [377,
#    22],
#   'ACH-000381;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [378,
#    7],
#   'ACH-000381;Cc1[nH]c(C=C2C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cccc4Cl)cc32)c(C)c1C(=O)N1CCCC1CN1CCCC1': [378,
#    16],
#   'ACH-000381;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [378,
#    18],
#   'ACH-000381;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [378, 19],
#   'ACH-000720;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [379,
#    3],
#   'ACH-000720;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [379, 15],
#   'ACH-000647;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [380, 11],
#   'ACH-000647;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [380,
#    17],
#   'ACH-000647;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [380,
#    18],
#   'ACH-000647;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [380, 19],
#   'ACH-000647;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [380,
#    22],
#   'ACH-000488;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [381,
#    21],
#   'ACH-000488;CN1CCN(CCOc2cc(OC3CCOCC3)c3c(Nc4c(Cl)ccc5c4OCO5)ncnc3c2)CC1': [381,
#    18],
#   'ACH-000353;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [382, 1],
#   'ACH-000408;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [383,
#    3],
#   'ACH-000408;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [383, 5],
#   'ACH-000408;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [383, 6],
#   'ACH-000408;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [383,
#    13],
#   'ACH-000408;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [383, 15],
#   'ACH-000408;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [383, 19],
#   'ACH-000051;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [384,
#    22],
#   'ACH-000694;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [385,
#    13],
#   'ACH-000694;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [385,
#    14],
#   'ACH-000694;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [385,
#    22],
#   'ACH-000397;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [386, 6],
#   'ACH-000397;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [386,
#    13],
#   'ACH-000397;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [386,
#    20],
#   'ACH-000285;Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': [387, 9],
#   'ACH-000048;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [388, 1],
#   'ACH-000885;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [389,
#    3],
#   'ACH-000885;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [389,
#    22],
#   'ACH-000716;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [390, 2],
#   'ACH-000716;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [390,
#    7],
#   'ACH-000716;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [390,
#    17],
#   'ACH-000430;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [391, 5],
#   'ACH-000430;CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(Cl)cc23)c1F': [391, 11],
#   'ACH-000430;CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)cc(F)cc1Cl': [391, 19],
#   'ACH-000040;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [392,
#    13],
#   'ACH-000040;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [392,
#    14],
#   'ACH-000040;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [392,
#    21],
#   'ACH-000364;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [393, 0],
#   'ACH-000364;COc1cc2c(Nc3ccc(Br)cc3F)ncnc2cc1OCC1CCN(C)CC1': [393, 1],
#   'ACH-000364;CCc1c2c(nc3ccc(OC(=O)N4CCC(N5CCCCC5)CC4)cc13)-c1cc3c(c(=O)n1C2)COC(=O)C3(O)CC': [393,
#    23],
#   'ACH-000364;Cn1c(Nc2ccc(C(F)(F)F)cc2)nc2cc(Oc3ccnc(-c4ncc(C(F)(F)F)[nH]4)c3)ccc21': [393,
#    12],
#   'ACH-000075;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [394, 0],
#   'ACH-000075;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [394, 6],
#   'ACH-000075;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [394, 15],
#   'ACH-000406;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [395, 5],
#   'ACH-000406;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [395,
#    8],
#   'ACH-000579;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [396,
#    14],
#   'ACH-000425;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [397, 2],
#   'ACH-000425;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [397,
#    13],
#   'ACH-000425;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [397,
#    20],
#   'ACH-000568;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [398,
#    14],
#   'ACH-000568;COc1ccc(C2=NC(c3ccc(Cl)cc3)C(c3ccc(Cl)cc3)N2C(=O)N2CCNC(=O)C2)c(OC(C)C)c1': [398,
#    17],
#   'ACH-000522;Cc1[nH]c2ccccc2c1CCNCc1ccc(C=CC(=O)NO)cc1': [399, 2],
#   'ACH-000522;COc1cc(N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc(Cl)c(Nc2ccccc2S(=O)(=O)C(C)C)n1': [399,
#    13],
#   'ACH-000484;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [400,
#    3],
#   'ACH-000484;CNC(C)C(=O)NC(C(=O)N1CCC2CCN(CCc3ccccc3)CC21)C1CCCCC1': [400, 5],
#   'ACH-000484;O=C(NOCC(O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F': [400, 6],
#   'ACH-000171;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [401,
#    20],
#   'ACH-000171;CS(=O)(=O)CCNCc1ccc(-c2ccc3ncnc(Nc4ccc(OCc5cccc(F)c5)c(Cl)c4)c3c2)o1': [401,
#    21],
#   'ACH-000304;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [402,
#    4],
#   'ACH-000304;CN1CCN(c2ccc3c(c2)NC(=C2C(=O)N=c4cccc(F)c4=C2N)N3)CC1': [402,
#    14],
#   'ACH-000661;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [403,
#    4],
#   'ACH-000827;C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1.Cl': [405, 15],
#   'ACH-000765;Nc1ncnc2c1c(-c1cccc(OCc3ccccc3)c1)cn2C1CC(CN2CCC2)C1': [407, 0],
#   'ACH-000570;CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': [408,
#    3],
#   'ACH-000570;CC(=O)O[C@H]1C(=O)[C@@]2(C)[C@H]([C@H](OC(=O)c3ccccc3)[C@]3(O)C[C@H](OC(=O)[C@H](O)[C@@H](NC(=O)c4ccccc4)c4ccccc4)C(C)=C1C3(C)C)[C@]1(OC(C)=O)CO[C@@H]1C[C@@H]2O': [408,
#    8],
#   'ACH-000570;C=CCNC1=C2CC(C)CC(OC)C(O)C(C)C=C(C)C(OC(N)=O)C(OC)C=CC=C(C)C(=O)NC(=CC1=O)C2=O': [408,
#    20],
#   'ACH-000828;CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C)c(O)ccc3[nH+]c2-1.[Cl-]': [410,
#    4],
#   'ACH-000828;CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': [410,
#    7],
#   'ACH-000828;CC(C)CC(NC(=O)C(Cc1ccccc1)CC(O)C(Cc1ccccc1)NC(=O)OC(C)(C)C)C(=O)NC(Cc1ccccc1)C(N)=O': [410,
#    22]})

# %% [markdown]
# ## combine result data

# %%
test_df = pd.read_csv(test_data_file, sep='\t', header=None)
columns = ['CELL_LINE', "DRUG", "RESPONSE"]
test_df.columns = columns

trained_model_results_df = pd.read_csv("NOTEBOOK/MODEL/Result/trained_model_drugcell.predict", header=None)
trained_model_results_df.columns = ['TRAINED_MODEL_RESPONSE']
pre_built_model_results_df = pd.read_csv("NOTEBOOK/MODEL/Result/prebuilt_model_drugcell.predict", header=None)
pre_built_model_results_df.columns = ['PREBUILT_MODEL_RESPONSE']
#pre_built_model_results_df
test_df['TRAINED_MODEL_RESPONSE'] = trained_model_results_df['TRAINED_MODEL_RESPONSE']
test_df['PREBUILT_MODEL_RESPONSE'] =pre_built_model_results_df['PREBUILT_MODEL_RESPONSE']
test_name = "NOTEBOOK/MODEL/Result/DrugCell_test_data.prediction_" + iteration + ".csv"
test_df.to_csv(test_name, index=False)
